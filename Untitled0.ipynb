# %%
import pandas as pd
import numpy as np
from google.colab import drive
from matplotlib import pyplot as plt
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Import

# %%
# %cd /content/drive/MyDrive/3401/Dataset/
# Out:
# /content/drive/MyDrive/3401/Dataset

# %%
credits= pd.read_csv("credits.csv")
titles=pd.read_csv("titles.csv")

# %%
combined = pd.merge(titles,credits,left_on="id",right_on="id")
combined = combined.drop('id', axis=1)
combined
# Out:
#              title   type                                        description  \
# 0      Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 1      Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 2      Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 3      Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# 4      Taxi Driver  MOVIE  A mentally unstable Vietnam War veteran works ...
# ...            ...    ...                                                ...
# 77796      Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77797      Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77798      Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77799      Lokillo  MOVIE  A controversial TV host and comedian who has b...
# 77800      Lokillo  MOVIE  A controversial TV host and comedian who has b...
#
# ...

# %%
shows = combined[combined['type'] != 'MOVIE']
shows
# Out:
#              id                         title  type  \
# 163     ts22164  Monty Python's Flying Circus  SHOW
# 164     ts22164  Monty Python's Flying Circus  SHOW
# 165     ts22164  Monty Python's Flying Circus  SHOW
# 166     ts22164  Monty Python's Flying Circus  SHOW
# 167     ts22164  Monty Python's Flying Circus  SHOW
# ...         ...                           ...   ...
# 77655  ts288861                     Let's Eat  SHOW
# 77656  ts288861                     Let's Eat  SHOW
# 77657  ts288861                     Let's Eat  SHOW
# 77658  ts288861                     Let's Eat  SHOW
# 77659  ts288861                     Let's Eat  SHOW
#
#                                              description  release_year  \
# 163    A British sketch comedy series with the shows ...          1969
# 164    A British sketch comedy series with the shows ...          1969
# 165    A British sketch comedy series with the shows ...          1969
# ...

# %% [markdown]
# TODO: Average score by genre
#
# TODO: Sort Actors by score

# %%
grouped_df = shows.groupby('title').agg(set).reset_index()
grouped_df
# Out:
#                                         title          id    type  \
# 0                                    #blackAF  {ts236033}  {SHOW}
# 1                          100 Days My Prince   {ts83359}  {SHOW}
# 2     100 Humans: Life's Questions. Answered.  {ts226588}  {SHOW}
# 3                              13 Reasons Why   {ts42294}  {SHOW}
# 4          13 Reasons Why: Beyond the Reasons   {ts82424}  {SHOW}
# ...                                       ...         ...     ...
# 1826                                revisions   {ts84639}  {SHOW}
# 1827                            นางสาวก้นครัว  {ts223454}  {SHOW}
# 1828                        ปริศนาล่าข้ามเวลา  {ts223062}  {SHOW}
# 1829                                 糖糖Online  {ts222901}  {SHOW}
# 1830                                   냉면 랩소디  {ts307816}  {SHOW}
#
#                                             description release_year  \
# 0     {A father takes an irreverent and honest appro...       {2020}
# ...
